# %% [markdown]
# #  MainCode

# %% [markdown]
# # Converting jpg images  of train + to png and saving them in the same directory

# %%
import os, sys
import cv2
import matplotlib.pyplot as plt
path = "../Dataset/Extra/Train/+/" #Source

dirs = os.listdir(path)


y=0

for item in dirs:

        y = y + 1
        print(path+item)
        arr = cv2.imread(path+item)
        copyImage = np.copy(arr)
        copyImage[arr > 175] = 0
        copyImage[arr <= 175] = 255
        
#         plt.imshow(copyImage)
#         plt.show()
        
        pilImage=Image.fromarray(copyImage.astype('uint8'), 'RGB')
        width, height = pilImage.size
        size = (28, 28)

        if width>=45 and height>=45:
             resizedImage = resizeimage.resize_cover(pilImage, size)
             mainarr=np.array(resizedImage)
             copyImage2 = np.copy(mainarr)
             copyImage2[mainarr > 90] = 255
             copyImage2[mainarr <= 90] = 0
             cv2.imwrite('../Dataset/Extra/Train/+B/' + y.__str__() + '.png', copyImage2)   
                
            
#              print(copyImage2.shape)
#              plt.imshow(copyImage2)
#              plt.show()
# Out:
# ../Dataset/Extra/Train/+/+_10.jpg
# ../Dataset/Extra/Train/+/+_100012.jpg
# ../Dataset/Extra/Train/+/+_100014.jpg
# ../Dataset/Extra/Train/+/+_100019.jpg
# ../Dataset/Extra/Train/+/+_100095.jpg
# ../Dataset/Extra/Train/+/+_100099.jpg
# ../Dataset/Extra/Train/+/+_100102.jpg
# ../Dataset/Extra/Train/+/+_10011.jpg
# ../Dataset/Extra/Train/+/+_100117.jpg
# ../Dataset/Extra/Train/+/+_100137.jpg
# ../Dataset/Extra/Train/+/+_10014.jpg
# ../Dataset/Extra/Train/+/+_100146.jpg
# ../Dataset/Extra/Train/+/+_100179.jpg
# ../Dataset/Extra/Train/+/+_10019.jpg
# ../Dataset/Extra/Train/+/+_100192.jpg
# ../Dataset/Extra/Train/+/+_100224.jpg
# ../Dataset/Extra/Train/+/+_100228.jpg
# ../Dataset/Extra/Train/+/+_10024.jpg
# ../Dataset/Extra/Train/+/+_100242.jpg
# ../Dataset/Extra/Train/+/+_100248.jpg
# ../Dataset/Extra/Train/+/+_100277.jpg
# ../Dataset/Extra/Train/+/+_100283.jpg
# ../Dataset/Extra/Train/+/+_10029.jpg
# ../Dataset/Extra/Train/+/+_100345.jpg
# ../Dataset/Extra/Train/+/+_100348.jpg
# ...

# %% [markdown]
# # Converting jpg images of train - to png and saving them in the same directory

# %%
import os, sys
import cv2
import matplotlib.pyplot as plt
path = "../Dataset/Extra/Train/-/" #Source

dirs = os.listdir(path)


y=0

for item in dirs:

        y = y + 1
        print(path+item)
        arr = cv2.imread(path+item)
        copyImage = np.copy(arr)
        copyImage[arr > 175] = 0
        copyImage[arr <= 175] = 255
        
#         plt.imshow(copyImage)
#         plt.show()
        
        pilImage=Image.fromarray(copyImage.astype('uint8'), 'RGB')
        width, height = pilImage.size
        size = (28, 28)

        if width>=45 and height>=45:
             resizedImage = resizeimage.resize_cover(pilImage, size)
             mainarr=np.array(resizedImage)
             copyImage2 = np.copy(mainarr)
             copyImage2[mainarr > 90] = 255
             copyImage2[mainarr <= 90] = 0
             cv2.imwrite('../Dataset/Extra/Train/-B/' + y.__str__() + '.png', copyImage2)
# Out:
# ../Dataset/Extra/Train/-/-_100005.jpg
# ../Dataset/Extra/Train/-/-_100007.jpg
# ../Dataset/Extra/Train/-/-_100009.jpg
# ../Dataset/Extra/Train/-/-_100015.jpg
# ../Dataset/Extra/Train/-/-_100021.jpg
# ../Dataset/Extra/Train/-/-_100025.jpg
# ../Dataset/Extra/Train/-/-_100027.jpg
# ../Dataset/Extra/Train/-/-_100028.jpg
# ../Dataset/Extra/Train/-/-_100031.jpg
# ../Dataset/Extra/Train/-/-_100033.jpg
# ../Dataset/Extra/Train/-/-_100038.jpg
# ../Dataset/Extra/Train/-/-_100039.jpg
# ../Dataset/Extra/Train/-/-_10004.jpg
# ../Dataset/Extra/Train/-/-_100044.jpg
# ../Dataset/Extra/Train/-/-_100048.jpg
# ../Dataset/Extra/Train/-/-_100055.jpg
# ../Dataset/Extra/Train/-/-_100059.jpg
# ../Dataset/Extra/Train/-/-_100078.jpg
# ../Dataset/Extra/Train/-/-_100090.jpg
# ../Dataset/Extra/Train/-/-_100108.jpg
# ../Dataset/Extra/Train/-/-_100111.jpg
# ../Dataset/Extra/Train/-/-_100121.jpg
# ../Dataset/Extra/Train/-/-_100124.jpg
# ../Dataset/Extra/Train/-/-_100130.jpg
# ../Dataset/Extra/Train/-/-_10016.jpg
# ...

# %% [markdown]
# # Converting jpg images of test +

# %%
import os, sys
import cv2
import matplotlib.pyplot as plt
path = "../Dataset/Extra/Test/+/" #Source

dirs = os.listdir(path)


y=0

for item in dirs:

        y = y + 1
        print(path+item)
        arr = cv2.imread(path+item)
        copyImage = np.copy(arr)
        copyImage[arr > 175] = 0
        copyImage[arr <= 175] = 255
        
#         plt.imshow(copyImage)
#         plt.show()
        
        pilImage=Image.fromarray(copyImage.astype('uint8'), 'RGB')
        width, height = pilImage.size
        size = (28, 28)

        if width>=45 and height>=45:
             resizedImage = resizeimage.resize_cover(pilImage, size)
             mainarr=np.array(resizedImage)
             copyImage2 = np.copy(mainarr)
             copyImage2[mainarr > 90] = 255
             copyImage2[mainarr <= 90] = 0
             cv2.imwrite('../Dataset/Extra/Test/+B/' + y.__str__() + '.png', copyImage2)
# Out:
# ../Dataset/Extra/Test/+/exp100129.jpg
# ../Dataset/Extra/Test/+/exp100133.jpg
# ../Dataset/Extra/Test/+/exp100145.jpg
# ../Dataset/Extra/Test/+/exp100176.jpg
# ../Dataset/Extra/Test/+/exp100189.jpg
# ../Dataset/Extra/Test/+/exp100203.jpg
# ../Dataset/Extra/Test/+/exp100240.jpg
# ../Dataset/Extra/Test/+/exp100244.jpg
# ../Dataset/Extra/Test/+/exp100256.jpg
# ../Dataset/Extra/Test/+/exp100304.jpg
# ../Dataset/Extra/Test/+/exp100334.jpg
# ../Dataset/Extra/Test/+/exp100350.jpg
# ../Dataset/Extra/Test/+/exp100353.jpg
# ../Dataset/Extra/Test/+/exp100379.jpg
# ../Dataset/Extra/Test/+/exp100382.jpg
# ../Dataset/Extra/Test/+/exp100396.jpg
# ../Dataset/Extra/Test/+/exp100411.jpg
# ../Dataset/Extra/Test/+/exp100418.jpg
# ../Dataset/Extra/Test/+/exp100453.jpg
# ../Dataset/Extra/Test/+/exp100459.jpg
# ../Dataset/Extra/Test/+/exp100463.jpg
# ../Dataset/Extra/Test/+/exp100475.jpg
# ../Dataset/Extra/Test/+/exp100477.jpg
# ../Dataset/Extra/Test/+/exp100514.jpg
# ../Dataset/Extra/Test/+/exp100667.jpg
# ...

# %% [markdown]
# # Converting jpg images of test -

# %%
import os, sys
import cv2
import matplotlib.pyplot as plt
path = "../Dataset/Extra/Test/-/" #Source

dirs = os.listdir(path)


y=0

for item in dirs:

        y = y + 1
        print(path+item)
        arr = cv2.imread(path+item)
        copyImage = np.copy(arr)
        copyImage[arr > 175] = 0
        copyImage[arr <= 175] = 255
        
#         plt.imshow(copyImage)
#         plt.show()
        
        pilImage=Image.fromarray(copyImage.astype('uint8'), 'RGB')
        width, height = pilImage.size
        size = (28, 28)

        if width>=45 and height>=45:
             resizedImage = resizeimage.resize_cover(pilImage, size)
             mainarr=np.array(resizedImage)
             copyImage2 = np.copy(mainarr)
             copyImage2[mainarr > 90] = 255
             copyImage2[mainarr <= 90] = 0
             cv2.imwrite('../Dataset/Extra/Test/-B/' + y.__str__() + '.png', copyImage2)
# Out:
# ../Dataset/Extra/Test/-/exp100000.jpg
# ../Dataset/Extra/Test/-/exp100016.jpg
# ../Dataset/Extra/Test/-/exp100051.jpg
# ../Dataset/Extra/Test/-/exp100057.jpg
# ../Dataset/Extra/Test/-/exp100070.jpg
# ../Dataset/Extra/Test/-/exp100080.jpg
# ../Dataset/Extra/Test/-/exp100082.jpg
# ../Dataset/Extra/Test/-/exp100083.jpg
# ../Dataset/Extra/Test/-/exp100087.jpg
# ../Dataset/Extra/Test/-/exp100098.jpg
# ../Dataset/Extra/Test/-/exp100111.jpg
# ../Dataset/Extra/Test/-/exp100114.jpg
# ../Dataset/Extra/Test/-/exp100127.jpg
# ../Dataset/Extra/Test/-/exp100147.jpg
# ../Dataset/Extra/Test/-/exp100161.jpg
# ../Dataset/Extra/Test/-/exp100177.jpg
# ../Dataset/Extra/Test/-/exp100190.jpg
# ../Dataset/Extra/Test/-/exp100200.jpg
# ../Dataset/Extra/Test/-/exp100211.jpg
# ../Dataset/Extra/Test/-/exp100218.jpg
# ../Dataset/Extra/Test/-/exp100231.jpg
# ../Dataset/Extra/Test/-/exp100238.jpg
# ../Dataset/Extra/Test/-/exp100258.jpg
# ../Dataset/Extra/Test/-/exp100295.jpg
# ../Dataset/Extra/Test/-/exp100299.jpg
# ...

# %% [markdown]
# # TESTING

# %%
import cv2
import numpy as np
img = cv2.imread('image4.png')

# %%
print(img.shape)
# Out:
# (28, 28, 3)

# %%
from PIL import Image

im = Image.open('image5.jpg')
im.save('image5.png')
img = cv2.imread('image5.png')

# %%
print(img.shape)
# Out:
# (45, 45, 3)

# %%
copyImage = np.copy(img)
copyImage[img > 127] = 255
copyImage[img <= 127] = 0

# %%
pilImage=Image.fromarray(copyImage.astype('uint8'), 'RGB')

# %%
print(pilImage)
# Out:
# <PIL.Image.Image image mode=RGB size=45x45 at 0x2200730EEF0>

# %%
import matplotlib.pyplot as plt
plt.imshow(copyImage)
plt.show()

# %%
print(type(pilImage))
# Out:
# <class 'PIL.Image.Image'>

# %%
from resizeimage import resizeimage
import cv2
import numpy as np

# %%
width, height = pilImage.size
size = (28, 28)

if width>=45 and height>=45:
     resizedImage = resizeimage.resize_cover(pilImage, size)
     arr=np.array(resizedImage)
     cv2.imwrite('y.png', arr)

# %%
import cv2
import numpy as np
img = cv2.imread('y.png')

# %%
print(img.shape)
# Out:
# (28, 28, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
plt.show()

# %%
copyImage = np.copy(img)
copyImage[img > 175] = 0
copyImage[img <= 175] = 255

# %%
import matplotlib.pyplot as plt
plt.imshow(copyImage)
plt.show()
